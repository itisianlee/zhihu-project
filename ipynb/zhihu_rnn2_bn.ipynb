# %%
import numpy as np
import tensorflow as tf
import utils9
import sys
import os
import pandas as pd
import pickle
import math
import time
import zhihu_rnn2_bn as rnn

# %%
word_dict = pickle.load(open('./ieee_zhihu_cup/word_dict' ,'r'))
char_dict = pickle.load(open('./ieee_zhihu_cup/char_dict' ,'r'))

# %%
cnn_seq_length = 60 
rnn_seq_length = 80
batch_size = 256
eval_batch_size = 2000
hidden_size = 180
lr = 0.005
reg_rate = 0.0001
epoch_num = 20
save_per_step = 1000
eval_per_step = 500
keep_prob = 0.5 
atn_hidden_size = 256
shuffle = True
ckpt_path = './models/'
num_sentences = 2
filter_sizes = [2,3,4,5,6,7]
num_filters = 256
decay_steps = 1000 
decay_rate = 0.90
vocab_size = len(word_dict) 
char_size = len(char_dict) 
embed_size = 128

summary_dir = './Log/'
max_score = 0.0
model_name = 'utils9-rnn-model'

# %%
utils = utils9.Utils(words_num=rnn_seq_length, chars_num=cnn_seq_length, batch_size=batch_size, 
                     eval_batch_size=eval_batch_size, dataset_dir='./ieee_zhihu_cup/', 
                     epoch_num=epoch_num, word_dict=word_dict, char_dict=char_dict, shuffle=True)

# %%
def train(sess, utils):
    # 生成数据
    batches = utils.generate_t_batch()
    eval_batches = utils.generate_e_batch()
    model = rnn.RNN_char_word(cnn_seq_length, rnn_seq_length, batch_size, eval_batch_size, hidden_size, 
                                lr, reg_rate, epoch_num, save_per_step, eval_per_step, keep_prob, 
                                atn_hidden_size, shuffle, ckpt_path, num_sentences, 
                                filter_sizes, num_filters, decay_steps, decay_rate, 
                                vocab_size, char_size, embed_size, is_train=True)
    sess.run(tf.global_variables_initializer())
    
    summary_writer = tf.summary.FileWriter(summary_dir, graph=tf.get_default_graph())
    
    for batch in batches:
        x_char, x_char_length, x_word, x_word_length, y = zip(*batch)
        batch_length = len(x_char)

        feed_dict = {model.cnn_input: x_char, 
                     model.rnn_input: x_word,
                     model.output_keep_prob: keep_prob,
                     model.batch_length: [batch_length],
                     model.labels: y,
                     model.word_input_len: x_word_length,
                     model.char_input_len: x_char_length}
        
        train_loss, step, summary, _= sess.run([model.loss, model.global_step, model.merged, model.train_op], 
                                                feed_dict) 
        summary_writer.add_summary(summary, step)
        if (step % eval_per_step == 0 and step > 10000):
            path = model.saver.save(sess, "models/"+model_name, global_step=step)
            print("Saved model checkpoint to {}".format(path))  
            print ("Step:",step)
            print ("Train loss:",train_loss)
            
            score_list = []
            eval_loss_list = []
            for i in range(40):
                x_char, x_char_length, x_word, x_word_length, y, real_labels = zip(*(eval_batches.next()))
                score, eval_loss = do_eval(utils, sess, model, x_char, x_char_length, 
                                           x_word, x_word_length, y, real_labels)
                score_list.append(score)
                eval_loss_list.append(eval_loss)
            print("avg eval loss:", np.mean(eval_loss_list))
            save_best_model(score_list, step) 
            
# 在验证集上做验证，报告损失、精确度
def do_eval(utils, sess, model, x_char, x_char_length, x_word, x_word_length, y, real_labels):
    predict_top_5 = tf.nn.top_k(model.logits, k=5)
    batch_length = len(x_char)
    feed_dict = {model.cnn_input: x_char, 
                 model.rnn_input: x_word,
                 model.output_keep_prob: 1.0,
                 model.batch_length: [batch_length],
                 model.labels: y,
                 model.word_input_len: x_word_length,
                 model.char_input_len: x_char_length}
    curr_eval_loss, predict_5 = sess.run([model.loss, predict_top_5], feed_dict)
#     print ("Evaluation loss:",curr_eval_loss)
#     print ("real_labels:",real_labels[:5])
#     print ("predict:",predict_5[1][:5])
#     print ("predict:",predict_5[0][:5])
    predict_label_and_marked_label_list = []
    for predict,label in zip(predict_5[1],real_labels):
        predict_label_and_marked_label_list.append((list(predict),list(label)))
    score = utils.eval(predict_label_and_marked_label_list)
    return score, curr_eval_loss
#     print("score:",score)
#     print "--------------------Parting Line---------------------"
    
def predict(utils, restore=True):
    with tf.Session() as sess:
        if restore:
            model = rnn.RNN_char_word(cnn_seq_length, rnn_seq_length, batch_size, eval_batch_size, hidden_size, 
                                        lr, reg_rate, epoch_num, save_per_step, eval_per_step, keep_prob, 
                                        atn_hidden_size, shuffle, ckpt_path, num_sentences, 
                                        filter_sizes, num_filters, decay_steps, decay_rate, 
                                        vocab_size, char_size, embed_size, is_train=False)
            model.saver.restore(sess=sess, save_path=tf.train.latest_checkpoint(ckpt_path))
        predict_top_5 = tf.nn.top_k(model.logits, k=5)
        pred_batches = utils.generate_p_batch()
        for count, pred_batch in enumerate(pred_batches):
            sys.stdout.write("Count %d\r" % count)
            sys.stdout.flush()
            x_char, x_char_length, x_word, x_word_length = zip(*(pred_batch))
            batch_length = len(x_char)
            feed_dict = {model.cnn_input: x_char, 
                         model.rnn_input: x_word,
                         model.output_keep_prob: 1.0,
                         model.batch_length: [batch_length],
                         model.word_input_len: x_word_length,
                         model.char_input_len: x_char_length}
            predict_5 = sess.run(predict_top_5, feed_dict=feed_dict)
            if count == 0:
                predict = predict_5[1]
            else:
                predict = np.concatenate((predict,predict_5[1]))
        np.savetxt("./Result/predict.txt",predict,fmt='%d')
        
def save_best_model(score_list, step):
    global max_score
    avg_score = np.mean(score_list)
    avg_score_str = "%d steps avg score: %f\n" % (step, avg_score) 
    file_name = 'avg_loss_file'
    save_path = './best_model/'
    if os.path.exists(save_path):
        wr = open(save_path + file_name, 'a')
        wr.write(avg_score_str)
        if avg_score > max_score:
            max_score = avg_score
            os.system('rm ./best_model/%s*' % model_name)
            os.system('cp ./models/%s-' % model_name + str(step) + '* ' + save_path)
    else:
        os.mkdir(save_path)
        os.system('cp ./models/%s-' % model_name + str(step) + '* ' + save_path)   
    print(avg_score_str)
    print "--------------------Parting Line---------------------"

# %%
with tf.Session() as sess:
    train(sess, utils)
# Out:
# Saved model checkpoint to models/utils9-rnn-model-10500
# ('Step:', 10500)
# ('Train loss:', 0.0044589015)
# ('avg eval loss:', 0.0041237078)
# 10500 steps avg score: 0.382478
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-11000
# ('Step:', 11000)
# ('Train loss:', 0.004385896)
# ('avg eval loss:', 0.0041215597)
# 11000 steps avg score: 0.383682
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-11500
# ('Step:', 11500)
# ('Train loss:', 0.0040990356)
# ('avg eval loss:', 0.0041202181)
# 11500 steps avg score: 0.382581
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-12000
# ('Step:', 12000)
# ('Train loss:', 0.0040471544)
# ('avg eval loss:', 0.0041349111)
# 12000 steps avg score: 0.383895
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-12500
# ('Step:', 12500)
# ('Train loss:', 0.004206622)
# ('avg eval loss:', 0.0040953108)
# 12500 steps avg score: 0.386494
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-13000
# ('Step:', 13000)
# ('Train loss:', 0.0038952162)
# ('avg eval loss:', 0.0041003777)
# 13000 steps avg score: 0.384313
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-13500
# ('Step:', 13500)
# ('Train loss:', 0.0040908479)
# ('avg eval loss:', 0.0040815203)
# 13500 steps avg score: 0.387446
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-14000
# ('Step:', 14000)
# ('Train loss:', 0.0039090174)
# ('avg eval loss:', 0.0040856348)
# 14000 steps avg score: 0.387397
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-14500
# ('Step:', 14500)
# ('Train loss:', 0.0041114981)
# ('avg eval loss:', 0.0040524439)
# 14500 steps avg score: 0.388469
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-15000
# ('Step:', 15000)
# ('Train loss:', 0.004109798)
# ('avg eval loss:', 0.0040437793)
# 15000 steps avg score: 0.389859
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-15500
# ('Step:', 15500)
# ('Train loss:', 0.0040933276)
# ('avg eval loss:', 0.0040262481)
# 15500 steps avg score: 0.391715
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-16000
# ('Step:', 16000)
# ('Train loss:', 0.0042313347)
# ('avg eval loss:', 0.0040337481)
# 16000 steps avg score: 0.388821
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-16500
# ('Step:', 16500)
# ('Train loss:', 0.0043658093)
# ('avg eval loss:', 0.0040311739)
# 16500 steps avg score: 0.390949
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-17000
# ('Step:', 17000)
# ('Train loss:', 0.0035954162)
# ('avg eval loss:', 0.0040018084)
# 17000 steps avg score: 0.391672
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-17500
# ('Step:', 17500)
# ('Train loss:', 0.0043235337)
# ('avg eval loss:', 0.0040053101)
# 17500 steps avg score: 0.392607
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-18000
# ('Step:', 18000)
# ('Train loss:', 0.0038181043)
# ('avg eval loss:', 0.0040052244)
# 18000 steps avg score: 0.392386
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-18500
# ('Step:', 18500)
# ('Train loss:', 0.0038650183)
# ('avg eval loss:', 0.0039998093)
# 18500 steps avg score: 0.392716
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-19000
# ('Step:', 19000)
# ('Train loss:', 0.0039923866)
# ('avg eval loss:', 0.0039799726)
# 19000 steps avg score: 0.396372
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-19500
# ('Step:', 19500)
# ('Train loss:', 0.003864215)
# ('avg eval loss:', 0.0039848969)
# 19500 steps avg score: 0.393694
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-20000
# ('Step:', 20000)
# ('Train loss:', 0.0038424595)
# ('avg eval loss:', 0.0039893067)
# 20000 steps avg score: 0.394790
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-20500
# ('Step:', 20500)
# ('Train loss:', 0.0040115537)
# ('avg eval loss:', 0.0039640246)
# 20500 steps avg score: 0.395981
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-21000
# ('Step:', 21000)
# ('Train loss:', 0.0039877971)
# ('avg eval loss:', 0.003961511)
# 21000 steps avg score: 0.397014
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-21500
# ('Step:', 21500)
# ('Train loss:', 0.0036795242)
# ('avg eval loss:', 0.0039645568)
# 21500 steps avg score: 0.395136
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-22000
# ('Step:', 22000)
# ('Train loss:', 0.004073862)
# ('avg eval loss:', 0.0039502704)
# 22000 steps avg score: 0.395673
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-22500
# ('Step:', 22500)
# ('Train loss:', 0.0042165858)
# ('avg eval loss:', 0.0039322814)
# 22500 steps avg score: 0.398093
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-23000
# ('Step:', 23000)
# ('Train loss:', 0.0038444598)
# ('avg eval loss:', 0.0039738379)
# 23000 steps avg score: 0.396365
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-23500
# ('Step:', 23500)
# ('Train loss:', 0.0039303051)
# ('avg eval loss:', 0.0039392672)
# 23500 steps avg score: 0.398582
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-24000
# ('Step:', 24000)
# ('Train loss:', 0.0035913277)
# ('avg eval loss:', 0.0039613275)
# 24000 steps avg score: 0.396329
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-24500
# ('Step:', 24500)
# ('Train loss:', 0.0035529768)
# ('avg eval loss:', 0.003977864)
# 24500 steps avg score: 0.396078
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-25000
# ('Step:', 25000)
# ('Train loss:', 0.0038149145)
# ('avg eval loss:', 0.0039657555)
# 25000 steps avg score: 0.399358
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-25500
# ('Step:', 25500)
# ('Train loss:', 0.0038230906)
# ('avg eval loss:', 0.0039467635)
# 25500 steps avg score: 0.399506
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-26000
# ('Step:', 26000)
# ('Train loss:', 0.0038570105)
# ('avg eval loss:', 0.0039344751)
# 26000 steps avg score: 0.398339
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-26500
# ('Step:', 26500)
# ('Train loss:', 0.0038116879)
# ('avg eval loss:', 0.003947244)
# 26500 steps avg score: 0.398333
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-27000
# ('Step:', 27000)
# ('Train loss:', 0.0040545207)
# ('avg eval loss:', 0.0039329091)
# 27000 steps avg score: 0.400730
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-27500
# ('Step:', 27500)
# ('Train loss:', 0.0037145459)
# ('avg eval loss:', 0.0039209318)
# 27500 steps avg score: 0.399455
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-28000
# ('Step:', 28000)
# ('Train loss:', 0.0035969177)
# ('avg eval loss:', 0.0039369189)
# 28000 steps avg score: 0.397734
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-28500
# ('Step:', 28500)
# ('Train loss:', 0.0034078849)
# ('avg eval loss:', 0.0039314828)
# 28500 steps avg score: 0.400680
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-29000
# ('Step:', 29000)
# ('Train loss:', 0.0036670305)
# ('avg eval loss:', 0.0039345538)
# 29000 steps avg score: 0.399260
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-29500
# ('Step:', 29500)
# ('Train loss:', 0.0036218108)
# ('avg eval loss:', 0.0039332975)
# 29500 steps avg score: 0.400023
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-30000
# ('Step:', 30000)
# ('Train loss:', 0.0037970671)
# ('avg eval loss:', 0.0039234776)
# 30000 steps avg score: 0.400955
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-30500
# ('Step:', 30500)
# ('Train loss:', 0.0037152828)
# ('avg eval loss:', 0.0039196634)
# 30500 steps avg score: 0.400152
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-31000
# ('Step:', 31000)
# ('Train loss:', 0.0039168475)
# ('avg eval loss:', 0.0039227949)
# 31000 steps avg score: 0.400728
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-31500
# ('Step:', 31500)
# ('Train loss:', 0.0036101656)
# ('avg eval loss:', 0.0038902604)
# 31500 steps avg score: 0.402856
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-32000
# ('Step:', 32000)
# ('Train loss:', 0.0039192229)
# ('avg eval loss:', 0.0039084032)
# 32000 steps avg score: 0.401756
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-32500
# ('Step:', 32500)
# ('Train loss:', 0.0035811362)
# ('avg eval loss:', 0.0038932585)
# 32500 steps avg score: 0.403009
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-33000
# ('Step:', 33000)
# ('Train loss:', 0.0038514419)
# ('avg eval loss:', 0.003904416)
# 33000 steps avg score: 0.401165
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-33500
# ('Step:', 33500)
# ('Train loss:', 0.0040507778)
# ('avg eval loss:', 0.0038941603)
# 33500 steps avg score: 0.404268
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-34000
# ('Step:', 34000)
# ('Train loss:', 0.0034428907)
# ('avg eval loss:', 0.0038850401)
# 34000 steps avg score: 0.403247
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-34500
# ('Step:', 34500)
# ('Train loss:', 0.003510636)
# ('avg eval loss:', 0.0039179437)
# 34500 steps avg score: 0.401329
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-35000
# ('Step:', 35000)
# ('Train loss:', 0.0033493405)
# ('avg eval loss:', 0.003921302)
# 35000 steps avg score: 0.402492
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-35500
# ('Step:', 35500)
# ('Train loss:', 0.0035382288)
# ('avg eval loss:', 0.0039364742)
# 35500 steps avg score: 0.401050
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-36000
# ('Step:', 36000)
# ('Train loss:', 0.0035592138)
# ('avg eval loss:', 0.003927642)
# 36000 steps avg score: 0.402435
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-36500
# ('Step:', 36500)
# ('Train loss:', 0.0037159836)
# ('avg eval loss:', 0.0039070807)
# 36500 steps avg score: 0.403206
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-37000
# ('Step:', 37000)
# ('Train loss:', 0.0034872415)
# ('avg eval loss:', 0.0039284648)
# 37000 steps avg score: 0.401477
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-37500
# ('Step:', 37500)
# ('Train loss:', 0.0033045535)
# ('avg eval loss:', 0.0039165812)
# 37500 steps avg score: 0.402892
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-38000
# ('Step:', 38000)
# ('Train loss:', 0.003350748)
# ('avg eval loss:', 0.0039084796)
# 38000 steps avg score: 0.402787
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-38500
# ('Step:', 38500)
# ('Train loss:', 0.0032953662)
# ('avg eval loss:', 0.0039342572)
# 38500 steps avg score: 0.402425
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-39000
# ('Step:', 39000)
# ('Train loss:', 0.0033422615)
# ('avg eval loss:', 0.0039294823)
# 39000 steps avg score: 0.401201
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-39500
# ('Step:', 39500)
# ('Train loss:', 0.0037124131)
# ('avg eval loss:', 0.0039145215)
# 39500 steps avg score: 0.402694
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-40000
# ('Step:', 40000)
# ('Train loss:', 0.0038444554)
# ('avg eval loss:', 0.0038968525)
# 40000 steps avg score: 0.403045
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-40500
# ('Step:', 40500)
# ('Train loss:', 0.0039013349)
# ('avg eval loss:', 0.0039182184)
# 40500 steps avg score: 0.402965
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-41000
# ('Step:', 41000)
# ('Train loss:', 0.0034400318)
# ('avg eval loss:', 0.0039195665)
# 41000 steps avg score: 0.402127
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-41500
# ('Step:', 41500)
# ('Train loss:', 0.003744391)
# ('avg eval loss:', 0.0039155907)
# 41500 steps avg score: 0.402239
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-42000
# ('Step:', 42000)
# ('Train loss:', 0.0037053991)
# ('avg eval loss:', 0.0039084377)
# 42000 steps avg score: 0.402405
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-42500
# ('Step:', 42500)
# ('Train loss:', 0.0035658979)
# ('avg eval loss:', 0.0039133518)
# 42500 steps avg score: 0.403287
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-43000
# ('Step:', 43000)
# ('Train loss:', 0.0036005906)
# ('avg eval loss:', 0.0038853895)
# 43000 steps avg score: 0.404034
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-43500
# ('Step:', 43500)
# ('Train loss:', 0.0036835626)
# ('avg eval loss:', 0.0039122035)
# 43500 steps avg score: 0.402352
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-44000
# ('Step:', 44000)
# ('Train loss:', 0.0035679596)
# ('avg eval loss:', 0.0039027794)
# 44000 steps avg score: 0.402349
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-44500
# ('Step:', 44500)
# ('Train loss:', 0.0037774893)
# ('avg eval loss:', 0.0039093322)
# 44500 steps avg score: 0.402994
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-45000
# ('Step:', 45000)
# ('Train loss:', 0.0034918578)
# ('avg eval loss:', 0.0038927891)
# 45000 steps avg score: 0.404205
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-45500
# ('Step:', 45500)
# ('Train loss:', 0.0032481465)
# ('avg eval loss:', 0.0039076186)
# 45500 steps avg score: 0.403150
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-46000
# ('Step:', 46000)
# ('Train loss:', 0.0033905576)
# ('avg eval loss:', 0.0039335722)
# 46000 steps avg score: 0.402650
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-46500
# ('Step:', 46500)
# ('Train loss:', 0.003456465)
# ('avg eval loss:', 0.0039411387)
# 46500 steps avg score: 0.401993
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-47000
# ('Step:', 47000)
# ('Train loss:', 0.0035935927)
# ('avg eval loss:', 0.0039547295)
# 47000 steps avg score: 0.402086
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-47500
# ('Step:', 47500)
# ('Train loss:', 0.0035288562)
# ('avg eval loss:', 0.0039446079)
# 47500 steps avg score: 0.401602
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-48000
# ('Step:', 48000)
# ('Train loss:', 0.0036948868)
# ('avg eval loss:', 0.0039259708)
# 48000 steps avg score: 0.403121
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-48500
# ('Step:', 48500)
# ('Train loss:', 0.0033783838)
# ('avg eval loss:', 0.0039651389)
# 48500 steps avg score: 0.400514
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-49000
# ('Step:', 49000)
# ('Train loss:', 0.0032751379)
# ('avg eval loss:', 0.003920977)
# 49000 steps avg score: 0.403524
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-49500
# ('Step:', 49500)
# ('Train loss:', 0.0037039614)
# ('avg eval loss:', 0.0039625308)
# 49500 steps avg score: 0.401341
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-50000
# ('Step:', 50000)
# ('Train loss:', 0.003361596)
# ('avg eval loss:', 0.0039241766)
# 50000 steps avg score: 0.405285
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-50500
# ('Step:', 50500)
# ('Train loss:', 0.0033876563)
# ('avg eval loss:', 0.0039435928)
# 50500 steps avg score: 0.401233
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-51000
# ('Step:', 51000)
# ('Train loss:', 0.0033886239)
# ('avg eval loss:', 0.0039499709)
# 51000 steps avg score: 0.401774
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-51500
# ('Step:', 51500)
# ('Train loss:', 0.0034621835)
# ('avg eval loss:', 0.0039515891)
# 51500 steps avg score: 0.401939
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-52000
# ('Step:', 52000)
# ('Train loss:', 0.0035477311)
# ('avg eval loss:', 0.0039451108)
# 52000 steps avg score: 0.401500
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-52500
# ('Step:', 52500)
# ('Train loss:', 0.0036681478)
# ('avg eval loss:', 0.0039453958)
# 52500 steps avg score: 0.401905
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-53000
# ('Step:', 53000)
# ('Train loss:', 0.0033635183)
# ('avg eval loss:', 0.0039415518)
# 53000 steps avg score: 0.402028
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-53500
# ('Step:', 53500)
# ('Train loss:', 0.0034245425)
# ('avg eval loss:', 0.0039200345)
# 53500 steps avg score: 0.402571
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-54000
# ('Step:', 54000)
# ('Train loss:', 0.0034099557)
# ('avg eval loss:', 0.0039272029)
# 54000 steps avg score: 0.402274
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-54500
# ('Step:', 54500)
# ('Train loss:', 0.0036360784)
# ('avg eval loss:', 0.0039422591)
# 54500 steps avg score: 0.403178
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-55000
# ('Step:', 55000)
# ('Train loss:', 0.0033674445)
# ('avg eval loss:', 0.0039457507)
# 55000 steps avg score: 0.401955
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-55500
# ('Step:', 55500)
# ('Train loss:', 0.0037170704)
# ('avg eval loss:', 0.0039319312)
# 55500 steps avg score: 0.402165
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-56000
# ('Step:', 56000)
# ('Train loss:', 0.0035095275)
# ('avg eval loss:', 0.0039337524)
# 56000 steps avg score: 0.403150
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-56500
# ('Step:', 56500)
# ('Train loss:', 0.0034123559)
# ('avg eval loss:', 0.0039305654)
# 56500 steps avg score: 0.403491
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/utils9-rnn-model-57000
# ('Step:', 57000)
# ('Train loss:', 0.0032654302)
# ('avg eval loss:', 0.0039611412)
# 57000 steps avg score: 0.402088
#
# --------------------Parting Line---------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-9ad522bf94b4> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     train(sess, utils)
#
# <ipython-input-5-996a56ad9d48> in train(sess, utils)
#      12     summary_writer = tf.summary.FileWriter(summary_dir, graph=tf.get_default_graph())
#      13
# ---> 14     for batch in batches:
#      15         x_char, x_char_length, x_word, x_word_length, y = zip(*batch)
#      16         batch_length = len(x_char)
#
# /home/jasperyang/ian/zhihu_project/Tensorflow/Tensorflow基础使用与文本分类应用/zhihu1/utils9.pyc in generate_t_batch(self)
#      42                 for i in xrange(reader.shape[0]):
#      43                     # 按','切分标签
# ---> 44                     temp = reader.iloc[i][4].split(',')
#      45                     # 如果分类数大于5，只取前5个分类
#      46                     if (len(temp)>5):
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1628                 self._is_valid_integer(key, axis)
#    1629
# -> 1630             return self._get_loc(key, axis=axis)
#    1631
#    1632     def _convert_to_indexer(self, obj, axis=0, is_setter=False):
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_loc(self, key, axis)
#     103
#     104     def _get_loc(self, key, axis=0):
# --> 105         return self.obj._ixs(key, axis=axis)
#     106
#     107     def _slice(self, obj, axis=0, kind=None):
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _ixs(self, i, axis)
#    1984                                                       index=self.columns,
#    1985                                                       name=self.index[i],
# -> 1986                                                       dtype=new_values.dtype)
#    1987                 result._set_is_copy(self, copy=copy)
#    1988                 return result
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     150
#     151             if index is not None:
# --> 152                 index = _ensure_index(index)
#     153
#     154             if data is None:
#
# KeyboardInterrupt:

# %%
print("params conf. file store success!")
predict(utils)
# Out:
# params conf. file store success!
# INFO:tensorflow:Restoring parameters from ./models/utils9-rnn-model-50000
# ('predict_set_num_batches:', 109)
# Count 108
