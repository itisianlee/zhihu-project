# %%
import numpy as np
import tensorflow as tf
import utils6
import sys
import os
import pandas as pd
import pickle
import math
import time
import zhihu_4split_rnn as rnn

# %%
word_dict = pickle.load(open('./ieee_zhihu_cup/word_dict' ,'r'))
char_dict = pickle.load(open('./ieee_zhihu_cup/char_dict' ,'r'))

# %%
cnn_seq_length = 40 
rnn_seq_length = 60
batch_size = 200
eval_batch_size = 2000
hidden_size = 256
lr = 0.005
reg_rate = 0.0001
epoch_num = 20
save_per_step = 1000
eval_per_step = 500
keep_prob = 0.5 
atn_hidden_size = 512
shuffle = True
ckpt_path = './models/'
num_sentences = 2
filter_sizes = [2,3,4,5,6,7]
num_filters = 256
decay_steps = 1000 
decay_rate = 0.90
vocab_size = len(word_dict) 
char_size = len(char_dict) 
embed_size = 128 
is_train = True

summary_dir = './Log/'
max_score = 0.0

# %%
utils = utils6.Utils(words_num=rnn_seq_length, chars_num=cnn_seq_length, batch_size=batch_size, 
                     eval_batch_size=eval_batch_size, dataset_dir='./ieee_zhihu_cup/', 
                     epoch_num=epoch_num, word_dict=word_dict, char_dict=char_dict, shuffle=True)

# %%
def train(sess, utils):
    # 生成数据
    batches = utils.generate_t_batch()
    eval_batches = utils.generate_e_batch()
    model = rnn.RNN_char_word(cnn_seq_length, rnn_seq_length, batch_size, eval_batch_size, hidden_size, 
                                lr, reg_rate, epoch_num, save_per_step, eval_per_step, keep_prob, 
                                atn_hidden_size, shuffle, ckpt_path, num_sentences, 
                                filter_sizes, num_filters, decay_steps, decay_rate, 
                                vocab_size, char_size, embed_size, is_train)
    sess.run(tf.global_variables_initializer())
    
    summary_writer = tf.summary.FileWriter(summary_dir, graph=tf.get_default_graph())
    
    for batch in batches:
        x_char1, x_char2, x_word_tit, x_word_des, x_word_len_tit, x_word_len_des, y = zip(*batch)
        rnn_input = np.concatenate((x_word_tit, x_word_des), axis=1)
        x_char = np.concatenate((x_char1, x_char2), axis=1)
        batch_length = len(x_char)

        feed_dict = {model.cnn_input: x_char, 
                     model.rnn_input: rnn_input,
                     model.output_keep_prob: keep_prob,
                     model.batch_length:[batch_length],
                     model.labels:y,
                     model.tit_input_len:x_word_len_tit,
                     model.des_input_len:x_word_len_des,
                     model.char_input_len:[cnn_seq_length] * batch_length}
        
        train_loss, step, summary, _= sess.run([model.loss, model.global_step, model.merged, model.train_op], 
                                                feed_dict) 
        summary_writer.add_summary(summary, step)
        if (step % eval_per_step == 0 and step > 10000):
            path = model.saver.save(sess, "models/4split-rnn-model", global_step=step)
            print("Saved model checkpoint to {}".format(path))  
            
            print ("Step:",step)
            print ("Train loss:",train_loss)
            
            score_list = []
            eval_loss_list = []
            for i in range(20):
                x_char1, x_char2, x_word_tit, x_word_des, x_word_len_tit, x_word_len_des, y, real_labels = \
                zip(*(eval_batches.next()))
                x_char = np.concatenate((x_char1, x_char2), axis=1)
                x_eval_batch = np.concatenate((x_word_tit, x_word_des), axis=1)
                score, eval_loss = do_eval(utils, sess, model, x_char, x_eval_batch, 
                                           x_word_len_tit, x_word_len_des, y, real_labels)
                score_list.append(score)
                eval_loss_list.append(eval_loss)
            print("avg eval loss:", np.mean(eval_loss_list))
            save_best_model(score_list, step)
        # 每训练save_per_step次保存1次模型
#         if (step % save_per_step == 0):
#             path = model.saver.save(sess, "models/rnn-model", global_step=step)
#             print("Saved model checkpoint to {}".format(path))     
            
# 在验证集上做验证，报告损失、精确度
def do_eval(utils, sess, model, cnn_input, rnn_input,x_word_len_tit, x_word_len_des, y, real_labels):
    predict_top_5 = tf.nn.top_k(model.logits, k=5)
    batch_length = len(cnn_input)
    feed_dict = {model.cnn_input: cnn_input, 
                 model.rnn_input: rnn_input,
                 model.output_keep_prob: 1.0,
                 model.batch_length:[batch_length],
                 model.labels:y,
                 model.tit_input_len:x_word_len_tit,
                 model.des_input_len:x_word_len_des,
                 model.char_input_len:[cnn_seq_length] * batch_length}
    curr_eval_loss, predict_5 = sess.run([model.loss, predict_top_5], feed_dict)
#     print ("Evaluation loss:",curr_eval_loss)
#     print ("real_labels:",real_labels[:5])
#     print ("predict:",predict_5[1][:5])
#     print ("predict:",predict_5[0][:5])
    predict_label_and_marked_label_list = []
    for predict,label in zip(predict_5[1],real_labels):
        predict_label_and_marked_label_list.append((list(predict),list(label)))
    score = utils.eval(predict_label_and_marked_label_list)
    return score, curr_eval_loss
#     print("score:",score)
#     print "--------------------Parting Line---------------------"
    
def predict(utils, restore=True):
    with tf.Session() as sess:
        if restore:
            model = rnn.RNN_char_word(cnn_seq_length, rnn_seq_length, batch_size, eval_batch_size, hidden_size, 
                                        lr, reg_rate, epoch_num, save_per_step, eval_per_step, keep_prob, 
                                        atn_hidden_size, shuffle, ckpt_path, num_sentences, 
                                        filter_sizes, num_filters, decay_steps, decay_rate, 
                                        vocab_size, char_size, embed_size, is_train)
            model.saver.restore(sess=sess, save_path=tf.train.latest_checkpoint(ckpt_path))
        predict_top_5 = tf.nn.top_k(model.logits, k=5)
        pred_batches = utils.generate_p_batch()
        for count, pred_batch in enumerate(pred_batches):
            sys.stdout.write("Count %d\r" % count)
            sys.stdout.flush()
            x_char1, x_char2, x_word_tit, x_word_des, x_word_len_tit, x_word_len_des = zip(*(pred_batch))
            x_pred_batch = np.concatenate((x_word_tit, x_word_des), axis=1)
            x_char = np.concatenate((x_char1, x_char2), axis=1)
            batch_length = len(x_char)
            feed_dict = {model.cnn_input: x_char, 
                         model.rnn_input: x_pred_batch,
                         model.output_keep_prob: 1.0,
                         model.batch_length:[batch_length],
                         model.tit_input_len:x_word_len_tit,
                         model.des_input_len:x_word_len_des,
                         model.char_input_len:[cnn_seq_length] * batch_length}
            predict_5 = sess.run(predict_top_5, feed_dict=feed_dict)
            if count == 0:
                predict = predict_5[1]
            else:
                predict = np.concatenate((predict,predict_5[1]))
        np.savetxt("./Result/predict.txt",predict,fmt='%d')
        
def save_best_model(score_list, step):
    global max_score
    avg_score = np.mean(score_list)
    avg_score_str = "%d steps avg score: %f\n" % (step, avg_score) 
    file_name = 'avg_loss_file'
    save_path = './best_model/'
    if os.path.exists(save_path):
        wr = open(save_path + file_name, 'a')
        wr.write(avg_score_str)
        if avg_score > max_score:
            max_score = avg_score
            os.system('rm ./best_model/4split-rnn-model*')
            os.system('cp ./models/4split-rnn-model-' + str(step) + '* ' + save_path)
    else:
        os.mkdir(save_path)
        os.system('cp ./models/4split-rnn-model-' + str(step) + '* ' + save_path)   
    print(avg_score_str)
    print "--------------------Parting Line---------------------"

# %%
with tf.Session() as sess:
    train(sess, utils)
# Out:
# Saved model checkpoint to models/4split-rnn-model-10500
# ('Step:', 10500)
# ('Train loss:', 0.0049799997)
# ('avg eval loss:', 0.0044360226)
# 10500 steps avg score: 0.364880
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-11000
# ('Step:', 11000)
# ('Train loss:', 0.0041819345)
# ('avg eval loss:', 0.0044171833)
# 11000 steps avg score: 0.369507
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-11500
# ('Step:', 11500)
# ('Train loss:', 0.0046396009)
# ('avg eval loss:', 0.004386527)
# 11500 steps avg score: 0.369608
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-12000
# ('Step:', 12000)
# ('Train loss:', 0.0047443844)
# ('avg eval loss:', 0.0043947692)
# 12000 steps avg score: 0.373521
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-12500
# ('Step:', 12500)
# ('Train loss:', 0.0042859041)
# ('avg eval loss:', 0.0043793442)
# 12500 steps avg score: 0.372933
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-13000
# ('Step:', 13000)
# ('Train loss:', 0.0046792016)
# ('avg eval loss:', 0.004333273)
# 13000 steps avg score: 0.376906
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-13500
# ('Step:', 13500)
# ('Train loss:', 0.0045421994)
# ('avg eval loss:', 0.0043239566)
# 13500 steps avg score: 0.376823
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-14000
# ('Step:', 14000)
# ('Train loss:', 0.0041469783)
# ('avg eval loss:', 0.0043655769)
# 14000 steps avg score: 0.375030
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-14500
# ('Step:', 14500)
# ('Train loss:', 0.0042322045)
# ('avg eval loss:', 0.0043421192)
# 14500 steps avg score: 0.376999
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-15000
# ('Step:', 15000)
# ('Train loss:', 0.0042365245)
# ('avg eval loss:', 0.004353343)
# 15000 steps avg score: 0.377589
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-15500
# ('Step:', 15500)
# ('Train loss:', 0.0043514646)
# ('avg eval loss:', 0.0043534422)
# 15500 steps avg score: 0.373761
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-16000
# ('Step:', 16000)
# ('Train loss:', 0.0041234335)
# ('avg eval loss:', 0.0043213698)
# 16000 steps avg score: 0.377704
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-16500
# ('Step:', 16500)
# ('Train loss:', 0.0043728016)
# ('avg eval loss:', 0.0042784163)
# 16500 steps avg score: 0.379595
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-17000
# ('Step:', 17000)
# ('Train loss:', 0.0041769664)
# ('avg eval loss:', 0.0043051136)
# 17000 steps avg score: 0.378921
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-17500
# ('Step:', 17500)
# ('Train loss:', 0.004229086)
# ('avg eval loss:', 0.0043271887)
# 17500 steps avg score: 0.379376
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-18000
# ('Step:', 18000)
# ('Train loss:', 0.0040029832)
# ('avg eval loss:', 0.0042920327)
# 18000 steps avg score: 0.380573
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-18500
# ('Step:', 18500)
# ('Train loss:', 0.0037918179)
# ('avg eval loss:', 0.0043129902)
# 18500 steps avg score: 0.378806
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-19000
# ('Step:', 19000)
# ('Train loss:', 0.0042017167)
# ('avg eval loss:', 0.0042851167)
# 19000 steps avg score: 0.381913
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-19500
# ('Step:', 19500)
# ('Train loss:', 0.0045675384)
# ('avg eval loss:', 0.0043113614)
# 19500 steps avg score: 0.380846
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-20000
# ('Step:', 20000)
# ('Train loss:', 0.0045652008)
# ('avg eval loss:', 0.0042942557)
# 20000 steps avg score: 0.380331
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-20500
# ('Step:', 20500)
# ('Train loss:', 0.0042097475)
# ('avg eval loss:', 0.0043006521)
# 20500 steps avg score: 0.381792
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-21000
# ('Step:', 21000)
# ('Train loss:', 0.0043502268)
# ('avg eval loss:', 0.0042680958)
# 21000 steps avg score: 0.381730
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-21500
# ('Step:', 21500)
# ('Train loss:', 0.0044646603)
# ('avg eval loss:', 0.0042812685)
# 21500 steps avg score: 0.382132
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-22000
# ('Step:', 22000)
# ('Train loss:', 0.0039137257)
# ('avg eval loss:', 0.0043216674)
# 22000 steps avg score: 0.381048
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-22500
# ('Step:', 22500)
# ('Train loss:', 0.0043082996)
# ('avg eval loss:', 0.0042727971)
# 22500 steps avg score: 0.382075
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-23000
# ('Step:', 23000)
# ('Train loss:', 0.0043271347)
# ('avg eval loss:', 0.0042695319)
# 23000 steps avg score: 0.384490
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-23500
# ('Step:', 23500)
# ('Train loss:', 0.0044323932)
# ('avg eval loss:', 0.0042623384)
# 23500 steps avg score: 0.382618
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-24000
# ('Step:', 24000)
# ('Train loss:', 0.0039542536)
# ('avg eval loss:', 0.0042691748)
# 24000 steps avg score: 0.381930
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-24500
# ('Step:', 24500)
# ('Train loss:', 0.0040663066)
# ('avg eval loss:', 0.0042602257)
# 24500 steps avg score: 0.381858
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-25000
# ('Step:', 25000)
# ('Train loss:', 0.0040263571)
# ('avg eval loss:', 0.0042747809)
# 25000 steps avg score: 0.382761
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-25500
# ('Step:', 25500)
# ('Train loss:', 0.0041990755)
# ('avg eval loss:', 0.0042470731)
# 25500 steps avg score: 0.384667
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-26000
# ('Step:', 26000)
# ('Train loss:', 0.0040779221)
# ('avg eval loss:', 0.0042010522)
# 26000 steps avg score: 0.385963
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-26500
# ('Step:', 26500)
# ('Train loss:', 0.004314064)
# ('avg eval loss:', 0.0042334674)
# 26500 steps avg score: 0.385043
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-27000
# ('Step:', 27000)
# ('Train loss:', 0.0044918554)
# ('avg eval loss:', 0.0042284052)
# 27000 steps avg score: 0.385152
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-27500
# ('Step:', 27500)
# ('Train loss:', 0.0040861755)
# ('avg eval loss:', 0.0042780703)
# 27500 steps avg score: 0.383011
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-28000
# ('Step:', 28000)
# ('Train loss:', 0.0037404064)
# ('avg eval loss:', 0.0042653847)
# 28000 steps avg score: 0.384467
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-28500
# ('Step:', 28500)
# ('Train loss:', 0.0036120561)
# ('avg eval loss:', 0.0042654802)
# 28500 steps avg score: 0.384683
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-29000
# ('Step:', 29000)
# ('Train loss:', 0.0039640367)
# ('avg eval loss:', 0.0042398074)
# 29000 steps avg score: 0.387186
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-29500
# ('Step:', 29500)
# ('Train loss:', 0.0040114685)
# ('avg eval loss:', 0.0042724484)
# 29500 steps avg score: 0.381214
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-30000
# ('Step:', 30000)
# ('Train loss:', 0.0044055912)
# ('avg eval loss:', 0.0042550252)
# 30000 steps avg score: 0.385060
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-30500
# ('Step:', 30500)
# ('Train loss:', 0.0041340417)
# ('avg eval loss:', 0.0042620208)
# 30500 steps avg score: 0.384739
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-31000
# ('Step:', 31000)
# ('Train loss:', 0.0041361772)
# ('avg eval loss:', 0.0042348406)
# 31000 steps avg score: 0.386212
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-31500
# ('Step:', 31500)
# ('Train loss:', 0.003871883)
# ('avg eval loss:', 0.0042445613)
# 31500 steps avg score: 0.385408
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-32000
# ('Step:', 32000)
# ('Train loss:', 0.0038835059)
# ('avg eval loss:', 0.0042222138)
# 32000 steps avg score: 0.387554
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-32500
# ('Step:', 32500)
# ('Train loss:', 0.0041059991)
# ('avg eval loss:', 0.0042900317)
# 32500 steps avg score: 0.385316
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-33000
# ('Step:', 33000)
# ('Train loss:', 0.0039026788)
# ('avg eval loss:', 0.0042560324)
# 33000 steps avg score: 0.385375
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-33500
# ('Step:', 33500)
# ('Train loss:', 0.0039199125)
# ('avg eval loss:', 0.0042277873)
# 33500 steps avg score: 0.386552
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-34000
# ('Step:', 34000)
# ('Train loss:', 0.0041378317)
# ('avg eval loss:', 0.0042338064)
# 34000 steps avg score: 0.387987
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-34500
# ('Step:', 34500)
# ('Train loss:', 0.0042583691)
# ('avg eval loss:', 0.0042335941)
# 34500 steps avg score: 0.387218
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-35000
# ('Step:', 35000)
# ('Train loss:', 0.0039738789)
# ('avg eval loss:', 0.0041773603)
# 35000 steps avg score: 0.388359
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-35500
# ('Step:', 35500)
# ('Train loss:', 0.0039438037)
# ('avg eval loss:', 0.0042479979)
# 35500 steps avg score: 0.386334
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-36000
# ('Step:', 36000)
# ('Train loss:', 0.0035055971)
# ('avg eval loss:', 0.0042281053)
# 36000 steps avg score: 0.385617
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-36500
# ('Step:', 36500)
# ('Train loss:', 0.0036600498)
# ('avg eval loss:', 0.0042239497)
# 36500 steps avg score: 0.386340
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-37000
# ('Step:', 37000)
# ('Train loss:', 0.0041453941)
# ('avg eval loss:', 0.0042187916)
# 37000 steps avg score: 0.387138
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-37500
# ('Step:', 37500)
# ('Train loss:', 0.0044121034)
# ('avg eval loss:', 0.004217986)
# 37500 steps avg score: 0.385796
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-38000
# ('Step:', 38000)
# ('Train loss:', 0.0039743967)
# ('avg eval loss:', 0.0042285239)
# 38000 steps avg score: 0.389457
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-38500
# ('Step:', 38500)
# ('Train loss:', 0.0037436988)
# ('avg eval loss:', 0.0042314054)
# 38500 steps avg score: 0.388926
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-39000
# ('Step:', 39000)
# ('Train loss:', 0.0039753704)
# ('avg eval loss:', 0.0041923048)
# 39000 steps avg score: 0.389378
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-39500
# ('Step:', 39500)
# ('Train loss:', 0.0039717807)
# ('avg eval loss:', 0.0042213653)
# 39500 steps avg score: 0.387687
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-40000
# ('Step:', 40000)
# ('Train loss:', 0.0038298727)
# ('avg eval loss:', 0.0042345305)
# 40000 steps avg score: 0.387215
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-40500
# ('Step:', 40500)
# ('Train loss:', 0.0041558282)
# ('avg eval loss:', 0.004164062)
# 40500 steps avg score: 0.392627
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-41000
# ('Step:', 41000)
# ('Train loss:', 0.0039228629)
# ('avg eval loss:', 0.0042347712)
# 41000 steps avg score: 0.387908
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-41500
# ('Step:', 41500)
# ('Train loss:', 0.0033549389)
# ('avg eval loss:', 0.0042320262)
# 41500 steps avg score: 0.387066
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-42000
# ('Step:', 42000)
# ('Train loss:', 0.0037041479)
# ('avg eval loss:', 0.0042290902)
# 42000 steps avg score: 0.387266
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-42500
# ('Step:', 42500)
# ('Train loss:', 0.0036668787)
# ('avg eval loss:', 0.0042025875)
# 42500 steps avg score: 0.390156
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-43000
# ('Step:', 43000)
# ('Train loss:', 0.0039384211)
# ('avg eval loss:', 0.0042422544)
# 43000 steps avg score: 0.389362
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-43500
# ('Step:', 43500)
# ('Train loss:', 0.0037236304)
# ('avg eval loss:', 0.0042571351)
# 43500 steps avg score: 0.386537
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-44000
# ('Step:', 44000)
# ('Train loss:', 0.0039187204)
# ('avg eval loss:', 0.0042330688)
# 44000 steps avg score: 0.387890
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-44500
# ('Step:', 44500)
# ('Train loss:', 0.003807707)
# ('avg eval loss:', 0.0042318795)
# 44500 steps avg score: 0.388839
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-45000
# ('Step:', 45000)
# ('Train loss:', 0.0036797074)
# ('avg eval loss:', 0.0042212093)
# 45000 steps avg score: 0.388160
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-45500
# ('Step:', 45500)
# ('Train loss:', 0.0039376887)
# ('avg eval loss:', 0.0042365748)
# 45500 steps avg score: 0.387853
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-46000
# ('Step:', 46000)
# ('Train loss:', 0.0035157122)
# ('avg eval loss:', 0.0041954834)
# 46000 steps avg score: 0.391242
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-46500
# ('Step:', 46500)
# ('Train loss:', 0.0039568702)
# ('avg eval loss:', 0.0042309193)
# 46500 steps avg score: 0.389334
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-47000
# ('Step:', 47000)
# ('Train loss:', 0.0036168536)
# ('avg eval loss:', 0.0042397846)
# 47000 steps avg score: 0.387946
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-47500
# ('Step:', 47500)
# ('Train loss:', 0.0038986809)
# ('avg eval loss:', 0.0042666513)
# 47500 steps avg score: 0.387229
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-48000
# ('Step:', 48000)
# ('Train loss:', 0.0039888341)
# ('avg eval loss:', 0.0042309561)
# 48000 steps avg score: 0.388813
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-48500
# ('Step:', 48500)
# ('Train loss:', 0.0038085666)
# ('avg eval loss:', 0.0042016329)
# 48500 steps avg score: 0.388503
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-49000
# ('Step:', 49000)
# ('Train loss:', 0.0039170203)
# ('avg eval loss:', 0.00419473)
# 49000 steps avg score: 0.392497
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-49500
# ('Step:', 49500)
# ('Train loss:', 0.0037519303)
# ('avg eval loss:', 0.0042333975)
# 49500 steps avg score: 0.387776
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-50000
# ('Step:', 50000)
# ('Train loss:', 0.0035676709)
# ('avg eval loss:', 0.0042436542)
# 50000 steps avg score: 0.387825
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-50500
# ('Step:', 50500)
# ('Train loss:', 0.0037671849)
# ('avg eval loss:', 0.0042065633)
# 50500 steps avg score: 0.389805
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-51000
# ('Step:', 51000)
# ('Train loss:', 0.0035667543)
# ('avg eval loss:', 0.0041716411)
# 51000 steps avg score: 0.391550
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-51500
# ('Step:', 51500)
# ('Train loss:', 0.0034756174)
# ('avg eval loss:', 0.0042265505)
# 51500 steps avg score: 0.388873
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-52000
# ('Step:', 52000)
# ('Train loss:', 0.003729342)
# ('avg eval loss:', 0.0041995863)
# 52000 steps avg score: 0.390333
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-52500
# ('Step:', 52500)
# ('Train loss:', 0.0039487812)
# ('avg eval loss:', 0.0041880766)
# 52500 steps avg score: 0.390629
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-53000
# ('Step:', 53000)
# ('Train loss:', 0.0038867833)
# ('avg eval loss:', 0.004197367)
# 53000 steps avg score: 0.390673
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-53500
# ('Step:', 53500)
# ('Train loss:', 0.0040208758)
# ('avg eval loss:', 0.0042097713)
# 53500 steps avg score: 0.388165
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-54000
# ('Step:', 54000)
# ('Train loss:', 0.0035756389)
# ('avg eval loss:', 0.0041822004)
# 54000 steps avg score: 0.391428
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-54500
# ('Step:', 54500)
# ('Train loss:', 0.0035531062)
# ('avg eval loss:', 0.0042369128)
# 54500 steps avg score: 0.389050
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-55000
# ('Step:', 55000)
# ('Train loss:', 0.0035627803)
# ('avg eval loss:', 0.0042321198)
# 55000 steps avg score: 0.389366
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-55500
# ('Step:', 55500)
# ('Train loss:', 0.0039718682)
# ('avg eval loss:', 0.0042635612)
# 55500 steps avg score: 0.388521
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-56000
# ('Step:', 56000)
# ('Train loss:', 0.0038181252)
# ('avg eval loss:', 0.0042662295)
# 56000 steps avg score: 0.387180
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-56500
# ('Step:', 56500)
# ('Train loss:', 0.0036458818)
# ('avg eval loss:', 0.004247752)
# 56500 steps avg score: 0.388844
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-57000
# ('Step:', 57000)
# ('Train loss:', 0.0037209711)
# ('avg eval loss:', 0.0042371321)
# 57000 steps avg score: 0.388435
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-57500
# ('Step:', 57500)
# ('Train loss:', 0.0036343974)
# ('avg eval loss:', 0.0042606718)
# 57500 steps avg score: 0.387126
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-58000
# ('Step:', 58000)
# ('Train loss:', 0.0035055298)
# ('avg eval loss:', 0.0042490703)
# 58000 steps avg score: 0.387579
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-58500
# ('Step:', 58500)
# ('Train loss:', 0.0035669336)
# ('avg eval loss:', 0.0042448104)
# 58500 steps avg score: 0.388309
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-59000
# ('Step:', 59000)
# ('Train loss:', 0.0037774087)
# ('avg eval loss:', 0.0042286003)
# 59000 steps avg score: 0.387110
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-59500
# ('Step:', 59500)
# ('Train loss:', 0.0036515489)
# ('avg eval loss:', 0.0042404635)
# 59500 steps avg score: 0.388411
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-60000
# ('Step:', 60000)
# ('Train loss:', 0.0039667352)
# ('avg eval loss:', 0.004266148)
# 60000 steps avg score: 0.386370
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-60500
# ('Step:', 60500)
# ('Train loss:', 0.0038495099)
# ('avg eval loss:', 0.0042583901)
# 60500 steps avg score: 0.388190
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-61000
# ('Step:', 61000)
# ('Train loss:', 0.0034008741)
# ('avg eval loss:', 0.0042536999)
# 61000 steps avg score: 0.387066
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-61500
# ('Step:', 61500)
# ('Train loss:', 0.0038346318)
# ('avg eval loss:', 0.00422042)
# 61500 steps avg score: 0.388023
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-62000
# ('Step:', 62000)
# ('Train loss:', 0.0036828974)
# ('avg eval loss:', 0.0042285658)
# 62000 steps avg score: 0.388384
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-62500
# ('Step:', 62500)
# ('Train loss:', 0.0041331011)
# ('avg eval loss:', 0.0042522503)
# 62500 steps avg score: 0.386329
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-63000
# ('Step:', 63000)
# ('Train loss:', 0.0036730329)
# ('avg eval loss:', 0.0042529614)
# 63000 steps avg score: 0.388833
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-63500
# ('Step:', 63500)
# ('Train loss:', 0.0033246388)
# ('avg eval loss:', 0.0042389915)
# 63500 steps avg score: 0.389005
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-64000
# ('Step:', 64000)
# ('Train loss:', 0.0032780091)
# ('avg eval loss:', 0.0042591053)
# 64000 steps avg score: 0.386093
#
# --------------------Parting Line---------------------
# Saved model checkpoint to models/4split-rnn-model-64500
# ('Step:', 64500)
# ('Train loss:', 0.0036480266)
# ('avg eval loss:', 0.0042618262)
# 64500 steps avg score: 0.386732
#
# --------------------Parting Line---------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-9ad522bf94b4> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     train(sess, utils)
#
# <ipython-input-5-73ac31163e73> in train(sess, utils)
#      28
#      29         train_loss, step, summary, _= sess.run([model.loss, model.global_step, model.merged, model.train_op],
# ---> 30                                                 feed_dict)
#      31         summary_writer.add_summary(summary, step)
#      32         if (step % eval_per_step == 0 and step > 10000):
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /home/jasperyang/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
print("params conf. file store success!")
predict(utils)
# Out:
# params conf. file store success!
# INFO:tensorflow:Restoring parameters from ./models/4split-rnn-model-40500
# ('predict_set_num_batches:', 109)
# Count 108

# %%
batches = utils.generate_e_batch()

# %%
x_char1,x_char2, x_word_tit, x_word_des, x_word_len_tit, x_word_len_des ,y,r= zip(*(batches.next()))
